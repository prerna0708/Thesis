# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import os
pd.options.mode.chained_assignment = None  # default='warn'

# %%
directory = os.getcwd()
path = directory + '/Data/'

# %% [markdown]
# ## Reading files

# %%
Centrality=pd.read_csv(path + 'df_final_graphoptions.csv')
Centrality_wo_options=pd.read_csv(path + 'df_final_graph_wo_options.csv')

# %% [markdown]
# ## Calculating Put Call ratio for the entire graph

# %%
Put=Centrality['Degree_reverse_wt_put'].sum()
Call=Centrality['Degree_reverse_wt_call'].sum()
Ratio=Put/Call
Ratio
# Out:
# 0.55388198470707

# %% [markdown]
# ## Calculating Put Call ratio for companies

# %%
Centrality['Degree_reverse_wt_put'] = Centrality['Degree_reverse_wt_put'].replace([0],1)
Centrality['Degree_reverse_wt_call'] = Centrality['Degree_reverse_wt_call'].replace([0],1)

# %%
Centrality["put_call_ratio"]=(Centrality['Degree_reverse_wt_put'])/(Centrality['Degree_reverse_wt_call'])
Centrality.replace([np.inf, -np.inf], 0, inplace=True)

# %% [markdown]
# ## Sorting based on Degree_natural_wt

# %%
Centrality=Centrality.sort_values(by=['Degree_natural_wt'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:15]

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10),  sharey=True)

sns.barplot(ax=axes[0,0], x="Degree_natural_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,0].set_title('Degree_natural_wt')

sns.barplot(ax=axes[0,1], x="Degree_reverse_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,1].set_title('Degree_reverse_wt')

sns.barplot(ax=axes[0,2], x="Page_Rank_wt_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,2].set_title('Page_Rank_wt_natural')

sns.barplot(ax=axes[1,0], x="Closeness_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,0].set_title('Closeness_natural')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,2], x="put_call_ratio", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,2].set_title('put_call_ratio')
# Out:
# Text(0.5, 1.0, 'put_call_ratio')

# %% [markdown]
# ## Sorting based on Degree_reverse_wt

# %%
Centrality=Centrality.sort_values(by=['Degree_reverse_wt'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:15]
fig, axes = plt.subplots( 2,3, figsize=(20, 10),  sharey=True)

sns.barplot(ax=axes[0,0], x="Degree_natural_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,0].set_title('Degree_natural_wt')

sns.barplot(ax=axes[0,1], x="Degree_reverse_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,1].set_title('Degree_reverse_wt')

sns.barplot(ax=axes[0,2], x="Page_Rank_wt_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,2].set_title('Page_Rank_wt_natural')

sns.barplot(ax=axes[1,0], x="Closeness_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,0].set_title('Closeness_natural')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,2], x="put_call_ratio", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,2].set_title('put_call_ratio ')
# Out:
# Text(0.5, 1.0, 'put_call_ratio ')

# %% [markdown]
# ## Sorting based on PageRank

# %%
Centrality=Centrality.sort_values(by=['Page_Rank_wt_natural'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:15]
fig, axes = plt.subplots(2, 3, figsize=(20, 10),  sharey=True)

sns.barplot(ax=axes[0,0], x="Degree_natural_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,0].set_title('Degree_natural_wt')

sns.barplot(ax=axes[0,1], x="Degree_reverse_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,1].set_title('Degree_reverse_wt')

sns.barplot(ax=axes[0,2], x="Page_Rank_wt_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,2].set_title('Page_Rank_wt_natural')

sns.barplot(ax=axes[1,0], x="Closeness_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,0].set_title('Closeness_natural')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,2], x="put_call_ratio", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,2].set_title('put_call_ratio')
# Out:
# Text(0.5, 1.0, 'put_call_ratio')

# %% [markdown]
# ## Sorting based on put call ratio

# %%
Centrality=Centrality.sort_values(by=['put_call_ratio'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:15]
fig, axes = plt.subplots(2, 3, figsize=(20, 10),  sharey=True)

sns.barplot(ax=axes[0,0], x="Degree_natural_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,0].set_title('Degree_natural_wt')

sns.barplot(ax=axes[0,1], x="Degree_reverse_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,1].set_title('Degree_reverse_wt')

sns.barplot(ax=axes[0,2], x="Page_Rank_wt_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,2].set_title('Page_Rank_wt_natural')

sns.barplot(ax=axes[1,0], x="Closeness_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,0].set_title('Closeness_natural')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,2], x="put_call_ratio", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,2].set_title('put_call_ratio')
# Out:
# Text(0.5, 1.0, 'put_call_ratio')

# %%
Centrality=Centrality.sort_values(by=['put_call_ratio']).reset_index(drop=True)
df=Centrality.iloc[0:15]
fig, axes = plt.subplots(2, 3, figsize=(20, 10),  sharey=True)

sns.barplot(ax=axes[0,0], x="Degree_natural_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,0].set_title('Degree_natural_wt')

sns.barplot(ax=axes[0,1], x="Degree_reverse_wt", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,1].set_title('Degree_reverse_wt')

sns.barplot(ax=axes[0,2], x="Page_Rank_wt_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,2].set_title('Page_Rank_wt_natural')

sns.barplot(ax=axes[1,0], x="Closeness_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,0].set_title('Closeness_natural')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')

sns.barplot(ax=axes[1,2], x="put_call_ratio", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,2].set_title('Lowest put_call_ratio')
# Out:
# Text(0.5, 1.0, 'Lowest put_call_ratio')

# %% [markdown]
# ## High put call ratio

# %%
Centrality=Centrality.sort_values(by=['put_call_ratio'], ascending=False).reset_index(drop=True)
sns.set(font_scale = 2)
df=Centrality.iloc[0:20]
fig, axes = plt.subplots(1, 1, figsize=(20, 10),  sharey=True)
axes.get_xaxis().get_major_formatter().set_scientific(False)

sns.barplot( x="put_call_ratio", y="name", data=df,
                 color="salmon", saturation=.5).set_title('put_call_ratio')
# Out:
# Text(0.5, 1.0, 'put_call_ratio')

# %% [markdown]
# ## Low put call ratio

# %%
Centrality=Centrality.sort_values(by=['put_call_ratio'], ascending=True).reset_index(drop=True)
df=Centrality.iloc[0:20]
sns.set(font_scale = 2)
fig, axes = plt.subplots(1, 1, figsize=(20, 10),  sharey=True)
axes.get_xaxis().get_major_formatter().set_scientific(False)

sns.barplot( x="put_call_ratio", y="name", data=df,
                 color="salmon", saturation=.5).set_title('put_call_ratio')
# Out:
# Text(0.5, 1.0, 'put_call_ratio')

# %% [markdown]
# ## High Pagerank

# %%
Centrality=Centrality.sort_values(by=['Page_Rank_wt_natural'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:20]
sns.set(font_scale = 2)
fig, axes = plt.subplots(1, 1, figsize=(20, 10),  sharey=True)
axes.get_xaxis().get_major_formatter().set_scientific(False)

sns.barplot( x="Page_Rank_wt_natural", y="name", data=df,
                 color="salmon", saturation=.5).set_title('Page_Rank_wt_natural')
# Out:
# Text(0.5, 1.0, 'Page_Rank_wt_natural')
