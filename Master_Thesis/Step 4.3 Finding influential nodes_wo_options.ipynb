# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import os

# %%
directory = os.getcwd()
path = directory + '/Data/'

# %% [markdown]
# ## Reading files

# %%
Centrality=pd.read_csv(path + 'df_final_graph_wo_options.csv')
Centrality_rev=pd.read_csv(path + 'df_final_graph_wo_options_rev.csv')

# %%
Centrality.sort_values(by=['Closeness_natural'], ascending=False).reset_index(drop=True)
# Out:
#            cik                                name  Degree_natural  \
# 0      1611326         IRONNET CYBERSECURITY, INC.             0.0
# 1      1611737          KPCB DGF II ASSOCIATES LLC             1.0
# 2        19617                 JPMORGAN CHASE & CO          5964.0
# 3       895421                      MORGAN STANLEY          7520.0
# 4      1364742                        BLACKROCK IN          5467.0
# ...        ...                                 ...             ...
# 20969  1525334                      CIVITAS LEARNG             0.0
# 20970   743241                   LATTENO FOOD CORP             0.0
# 20971  1756161                 TUANCHE LIMITED/ADR             0.0
# 20972  1114643                        NE ENERGY RP             0.0
# 20973  1732988  PACTIV GENERAL EMPLOYEE BENEFIT TR             1.0
#
#        Degree_reverse  Degree_natural_wt  Degree_reverse_wt  Betweeness  \
# 0                 1.0                  0              25208           0
# ...

# %%
Centrality_rev.sort_values(by=['Closeness_natural'], ascending=False).reset_index(drop=True)
# Out:
#            cik                                name  Degree_natural  \
# 0      1611326         IRONNET CYBERSECURITY, INC.             1.0
# 1      1611737          KPCB DGF II ASSOCIATES LLC             0.0
# 2        19617                 JPMORGAN CHASE & CO          3783.0
# 3       895421                      MORGAN STANLEY          1717.0
# 4      1364742                        BLACKROCK IN          1943.0
# ...        ...                                 ...             ...
# 20969  1525334                      CIVITAS LEARNG             1.0
# 20970   743241                   LATTENO FOOD CORP             1.0
# 20971  1756161                 TUANCHE LIMITED/ADR             1.0
# 20972  1114643                        NE ENERGY RP             1.0
# 20973  1732988  PACTIV GENERAL EMPLOYEE BENEFIT TR             0.0
#
#        Degree_reverse  Degree_natural_wt  Degree_reverse_wt  Betweeness  \
# 0                 0.0              25208                  0           0
# ...

# %% [markdown]
# # Checking values of closeness and betweeness in different orientation

# %%
Centrality[Centrality['Closeness_natural']!=Centrality['Closeness_und']]
# Out:
# Empty DataFrame
# Columns: [cik, name, Degree_natural, Degree_reverse, Degree_natural_wt, Degree_reverse_wt, Betweeness, Betweeness_reverse, Ap_Betweeness_natural, Ap_Betweeness_reverse, Page_Rank_wt_natural, Page_Rank_wt_reverse, authScore_x, hubScore_x, authScore_y, hubScore_y, Closeness_natural, Closeness_reverse, Closeness_und]
# Index: []

# %%
Centrality[Centrality['Betweeness']!=Centrality['Betweeness_reverse']]
# Out:
# Empty DataFrame
# Columns: [cik, name, Degree_natural, Degree_reverse, Degree_natural_wt, Degree_reverse_wt, Betweeness, Betweeness_reverse, Ap_Betweeness_natural, Ap_Betweeness_reverse, Page_Rank_wt_natural, Page_Rank_wt_reverse, authScore_x, hubScore_x, authScore_y, hubScore_y, Closeness_natural, Closeness_reverse, Closeness_und]
# Index: []

# %% [markdown]
# ## Calculating money owed by respective companies

# %%
Centrality['id_od']=Centrality["Degree_reverse_wt"]-Centrality["Degree_natural_wt"]

# %% [markdown]
# ## Sorting based on money owed

# %%
Centrality=Centrality.sort_values(by=['id_od'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:19]

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 10),  sharey=True)

sns.barplot(ax=axes[0,0], x="id_od", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,0].set_title('indegree_outdegree')

sns.barplot(ax=axes[0,1], x="Page_Rank_wt_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,1].set_title('Page_Rank_wt_natural')

sns.barplot(ax=axes[1,0], x="Closeness_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,0].set_title('Closeness_natural')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')
# Out:
# Text(0.5, 1.0, 'Betweeness')

# %% [markdown]
# ## Sorting based on PageRank

# %%
Centrality=Centrality.sort_values(by=['Page_Rank_wt_natural'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:19]
fig, axes = plt.subplots(2, 2, figsize=(20, 10),  sharey=True)

sns.barplot(ax=axes[0,0], x="id_od", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,0].set_title('indegree_outdegree')

sns.barplot(ax=axes[0,1], x="Page_Rank_wt_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,1].set_title('Page_Rank_wt_natural')

sns.barplot(ax=axes[1,0], x="Closeness_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,0].set_title('Closeness_natural')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')
# Out:
# Text(0.5, 1.0, 'Betweeness')

# %% [markdown]
# ## Sorting based on Betweeness

# %%
Centrality=Centrality.sort_values(by=['Betweeness'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:19]
fig, axes = plt.subplots(2, 2, figsize=(20, 10),  sharey=True)

sns.barplot(ax=axes[0,0], x="id_od", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,0].set_title('indegree_outdegree')

sns.barplot(ax=axes[0,1], x="Page_Rank_wt_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[0,1].set_title('Page_Rank_wt_natural')

sns.barplot(ax=axes[1,0], x="Closeness_natural", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,0].set_title('Closeness_natural')

sns.barplot(ax=axes[1,1], x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5)
axes[1,1].set_title('Betweeness')
# Out:
# Text(0.5, 1.0, 'Betweeness')

# %%
Centrality=Centrality.sort_values(by=['Betweeness'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:19]
fig, axes = plt.subplots(1, 1, figsize=(20, 10),  sharey=True)

sns.barplot( x="Betweeness", y="name", data=df,
                 color="salmon", saturation=.5).set_title('Betweeness')
# Out:
# Text(0.5, 1.0, 'Betweeness')

# %%
Centrality=Centrality.sort_values(by=['Degree_reverse_wt'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:14]
fig, axes = plt.subplots(1, 1, figsize=(20, 10),  sharey=True)
axes.get_xaxis().get_major_formatter().set_scientific(False)
sns.barplot( x="Degree_reverse_wt", y="name", data=df,
                 color="salmon", saturation=.5).set_title('Degree_reverse_wt')
# Out:
# Text(0.5, 1.0, 'Degree_reverse_wt')

# %%
Centrality=Centrality.sort_values(by=['id_od'], ascending=False).reset_index(drop=True)
df=Centrality.iloc[0:14]
fig, axes = plt.subplots(1, 1, figsize=(20, 10),  sharey=True)

sns.barplot( x="id_od", y="name", data=df,
                 color="salmon", saturation=.5).set_title('id_od')


Centrality.head()
# Out:
#        cik                    name  Degree_natural  Degree_reverse  \
# 0   789019          MICROSOFT CORP             0.0          4602.0
# 1   320193              APPLE INC.             0.0          4449.0
# 2  1100663           ISHARES TRUST             0.0         58760.0
# 3  1652044           ALPHABET INC.             0.0          6317.0
# 4   884394  SPDR S&P 500 ETF TRUST             0.0         15204.0
#
#    Degree_natural_wt  Degree_reverse_wt  Betweeness  Betweeness_reverse  \
# 0                  0      1737380571727           0                   0
# 1                  0      1652904655961           0                   0
# 2                  0      1595270845411           0                   0
# 3                  0      1156094686897           0                   0
# 4                  0      1050314405880           0                   0
#
#    Ap_Betweeness_natural  Ap_Betweeness_reverse  Page_Rank_wt_natural  \
# ...
